# %%
# !wget -q https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task
# Out:
# 'wget'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
import cv2
import mediapipe as mp
import time

# ==============================================================================
# 1. MediaPipe Tasks API 핵심 클래스 로드
# ==============================================================================
# BaseOptions: 모델 파일 경로(.task) 및 디바이스(CPU/GPU) 설정 담당
BaseOptions = mp.tasks.BaseOptions

# HandLandmarker: 실제 손 관절 위치를 추론하는 메인 클래스
HandLandmarker = mp.tasks.vision.HandLandmarker

# HandLandmarkerOptions: 신뢰도 임계값, 인식 모드, 최대 손 개수 등을 세팅하는 옵션 클래스
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions

# VisionRunningMode: 입력 데이터 형태 정의 (IMAGE: 정지영상, VIDEO: 비디오 파일, LIVE_STREAM: 실시간 웹캠)
VisionRunningMode = mp.tasks.vision.RunningMode


# ==============================================================================
# 2. 손 관절(Landmark) 연결선 정의 (시각화용)
# ==============================================================================
# 21개 관절 점 인덱스를 기반으로 손가락 마디마디를 잇는 튜플 리스트
HAND_CONNECTIONS = [
    # 엄지손가락 (Wrist 0 -> 손목 base 1 -> 관절 2, 3 -> 손끝 4)
    (0, 1), (1, 2), (2, 3), (3, 4),
    
    # 검지손가락 (Wrist 0 -> 검지 뿌리 5 -> 관절 6, 7 -> 손끝 8)
    (0, 5), (5, 6), (6, 7), (7, 8),
    
    # 중지손가락 (검지 뿌리 5 -> 중지 뿌리 9 -> 관절 10, 11 -> 손끝 12)
    (5, 9), (9, 10), (10, 11), (11, 12),
    
    # 약지손가락 (중지 뿌리 9 -> 약지 뿌리 13 -> 관절 14, 15 -> 손끝 16)
    (9, 13), (13, 14), (14, 15), (15, 16),
    
    # 새끼손가락 (약지 뿌리 13 -> 새끼 뿌리 17 -> 관절 18, 19 -> 손끝 20 + 손목 0 연결)
    (13, 17), (0, 17), (17, 18), (18, 19), (19, 20)
]


# ==============================================================================
# 3. HandLandmarker 옵션 설정 및 모델 로드
# ==============================================================================
options = HandLandmarkerOptions(
    # 다운로드받은 모델 파일(.task)의 상대/절대 경로 지정
    base_options=BaseOptions(model_asset_path='hand_landmarker.task'),
    
    # 비디오 스트림 처리 모드로 설정 (동적 타임스탬프와 함께 연속 프레임 추적)
    running_mode=VisionRunningMode.VIDEO,
    
    # 화면 내 감지할 최대 손 개수 설정 (1로 설정 시 가장 명확한 손 1개만 추적)
    num_hands=1,
    
    # 손 탐지(Detection) 최소 신뢰도 (0.5 = 50% 이상 확신할 때 손으로 인식)
    min_hand_detection_confidence=0.5,
    
    # 손 추적(Tracking) 최소 신뢰도 (프레임 간 손의 위치를 계속 추적하는 임계값)
    min_tracking_confidence=0.5
)

# 기본 연결된 웹캠 장치 열기 (0: 기본 카메라)
cap = cv2.VideoCapture(0)


# ==============================================================================
# 4. 실시간 추론 및 시각화 루프
# ==============================================================================
# 'with' 문을 통해 Landmarker 객체를 안전하게 생성 (작업 종료 시 메모리 자원 자동 해제)
with HandLandmarker.create_from_options(options) as landmarker:
    while cap.isOpened():
        # 웹캠으로부터 1개 프레임 읽어오기 (ret: 성공여부 Boolean, frame: BGR 이미지 배열)
        ret, frame = cap.read()
        if not ret:
            print("카메라 프레임을 읽어올 수 없습니다.")
            break

        # 거울 모드 처리를 위한 좌우 반전 (1: 좌우 반전)
        frame = cv2.flip(frame, 1)
        
        # OpenCV의 BGR 색상 채널을 MediaPipe가 지원하는 RGB 채널로 변환
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # NumPy 배열 이미지를 MediaPipe의 전용 Image 객체로 래핑
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        
        # Tasks API VIDEO 모드 필수값: 밀리초(ms) 단위의 단조 증가 타임스탬프 생성
        frame_timestamp_ms = int(time.time() * 1000)
        
        # RGB 이미지와 타임스탬프를 모델에 전달하여 3D 관절 추론 실행
        result = landmarker.detect_for_video(mp_image, frame_timestamp_ms)

        # 원본 프레임의 높이(h), 너비(w) 추출 (정규화 좌표 -> 픽셀 좌표 변환용)
        h, w, _ = frame.shape
        
        # 손이 화면에서 성공적으로 감지되었는지 확인
        if result.hand_landmarks:
            # 감지된 손 개수만큼 반복 (num_hands=1 설정으로 최대 1회 실행)
            for hand_landmarks in result.hand_landmarks:
                pixel_coords = [] # 21개 관절의 (x, y) 픽셀 좌표를 담을 리스트
                
                # --------------------------------------------------------------
                # 4-1. 관절 점(Landmark) 위치 계산 및 출력
                # --------------------------------------------------------------
                for idx, lm in enumerate(hand_landmarks):
                    print(f'lm : {lm}')

                    # lm.x, lm.y는 0.0~1.0 사이로 정규화된 값이므로 해상도(w, h)를 곱해 픽셀 단위로 변환
                    # w : 이미지 넓이, h : 이미지 높이
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    if idx == 4:
                        # 4번 : 엄지손가락 끝
                        cv2.circle(frame, (cx, cy), 8, (255, 0, 0), -1)
                    elif idx == 8:
                        cv2.circle(frame, (cx, cy), 8, (0, 0, 255), -1)

                    pixel_coords.append((cx, cy))
                    
                    # 관절 위치에 녹색 원 그리기 (원 중심: cx,cy / 반지름: 4px / 색상: BGR (0,255,0) / 채우기: -1)
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 0), -1)

                # --------------------------------------------------------------
                # 4-2. 관절 마디 연결선 그리기
                # --------------------------------------------------------------
                for start_idx, end_idx in HAND_CONNECTIONS:
                    # HAND_CONNECTIONS 상의 두 관절 픽셀 좌표 획득
                    p1 = pixel_coords[start_idx]
                    p2 = pixel_coords[end_idx]
                    
                    # 두 점 사이에 파란색 직선 그리기 (색상: BGR (255,0,0) / 두께: 2px)
                    cv2.line(frame, p1, p2, (255, 0, 0), 2)

        # 처리 결과 프레임을 "Hand Recognition" 윈도우 창에 표시
        cv2.imshow("Hand Recognition", frame)

        # 5밀리초 동안 키 입력을 대기하고 8비트 마스크 적용
        key = cv2.waitKey(5) & 0xFF
        # ESC 키(ASCII 27) 또는 'q' 키를 누르면 루프 종료
        if key == 27 or key == ord('q'):
            break

# ==============================================================================
# 5. 자원 해제
# ==============================================================================
# 웹캠 장치 점유 해제
cap.release()

# 오픈되어 있는 모든 OpenCV 그래픽 창 닫기
cv2.destroyAllWindows()
# Out:
# lm : NormalizedLandmark(x=0.8842926621437073, y=1.009342908859253, z=4.5187487529574355e-08, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8272371292114258, y=0.9958698153495789, z=-0.045787032693624496, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7858965992927551, y=0.9479268193244934, z=-0.07881003618240356, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.758934497833252, y=0.8974328637123108, z=-0.10781338065862656, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7347375750541687, y=0.8516783714294434, z=-0.1383739411830902, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8389109373092651, y=0.8485564589500427, z=-0.06985489279031754, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8390044569969177, y=0.7647631764411926, z=-0.10215765982866287, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8457890748977661, y=0.7128786444664001, z=-0.12693741917610168, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8607338666915894, y=0.6700339317321777, z=-0.14576400816440582, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9041365385055542, y=0.8496354222297668, z=-0.06840766966342926, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9145920872688293, y=0.7547346353530884, z=-0.09400627762079239, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.926615834236145, y=0.6948754787445068, z=-0.11405829340219498, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9467068910598755, y=0.6500968933105469, z=-0.13198480010032654, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9577388167381287, y=0.8749629259109497, z=-0.07002302259206772, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9821078181266785, y=0.7814355492591858, z=-0.09929947555065155, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0014342069625854, y=0.7290922999382019, z=-0.1164741963148117, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.024330735206604, y=0.6901425123214722, z=-0.12906114757061005, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.002001166343689, y=0.9150826334953308, z=-0.07439106702804565, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0360199213027954, y=0.856535792350769, z=-0.10024222731590271, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0615473985671997, y=0.8226495981216431, z=-0.10960627347230911, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0854076147079468, y=0.7956775426864624, z=-0.11611610651016235, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8931624293327332, y=1.0541939735412598, z=7.305462759177317e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8261120319366455, y=1.0283989906311035, z=-0.05447639897465706, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7855706810951233, y=0.94834965467453, z=-0.08642258495092392, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7696491479873657, y=0.8668814301490784, z=-0.11075413972139359, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7420172095298767, y=0.7946966886520386, z=-0.13519400358200073, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8350164890289307, y=0.817669689655304, z=-0.06845586001873016, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8445748090744019, y=0.717200756072998, z=-0.1055585965514183, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8577603101730347, y=0.6535205841064453, z=-0.13384559750556946, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8761444687843323, y=0.5972785353660583, z=-0.1534663289785385, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8954210877418518, y=0.8148091435432434, z=-0.06271961331367493, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9184018969535828, y=0.7083438634872437, z=-0.09155037254095078, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9370813369750977, y=0.6399704217910767, z=-0.11514754593372345, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9600504636764526, y=0.5789778232574463, z=-0.13402120769023895, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9444405436515808, y=0.838551938533783, z=-0.061594631522893906, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9759175181388855, y=0.7405189871788025, z=-0.09048279374837875, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9986708164215088, y=0.6852130889892578, z=-0.10708556324243546, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0211793184280396, y=0.6337297558784485, z=-0.11988610029220581, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9837719798088074, y=0.880969226360321, z=-0.06447019428014755, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0218636989593506, y=0.8157358765602112, z=-0.09129469096660614, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0523115396499634, y=0.7817159295082092, z=-0.10077999532222748, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0789954662322998, y=0.7504532337188721, z=-0.10701288282871246, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8954165577888489, y=1.038856029510498, z=8.41933797346428e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8180669546127319, y=1.0020849704742432, z=-0.04771319031715393, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7778171300888062, y=0.9097219705581665, z=-0.07232573628425598, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7692230343818665, y=0.8173973560333252, z=-0.0888783410191536, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7464621067047119, y=0.7369325160980225, z=-0.10617747157812119, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8368819952011108, y=0.79079270362854, z=-0.06175977364182472, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8486267924308777, y=0.6788603663444519, z=-0.09382740408182144, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8618947267532349, y=0.6059881448745728, z=-0.11898194253444672, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8791178464889526, y=0.5424807071685791, z=-0.13725338876247406, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9026640057563782, y=0.7866448760032654, z=-0.058644700795412064, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9279500842094421, y=0.6707464456558228, z=-0.08148444443941116, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9494352340698242, y=0.5904068946838379, z=-0.10403767228126526, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9704300165176392, y=0.5227293968200684, z=-0.12220141291618347, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9526161551475525, y=0.8180137276649475, z=-0.05888906866312027, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9826351404190063, y=0.7133190631866455, z=-0.08809995651245117, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0043139457702637, y=0.6527628302574158, z=-0.10878661274909973, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0233485698699951, y=0.6012821793556213, z=-0.12451300770044327, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9917967915534973, y=0.870928943157196, z=-0.06149221956729889, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9983206391334534, y=0.8321256637573242, z=-0.09676436334848404, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9956544637680054, y=0.8228527307510376, z=-0.10910732299089432, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9927991628646851, y=0.8173584342002869, z=-0.11581610143184662, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8893559575080872, y=1.0450758934020996, z=8.266904387710383e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8150297403335571, y=0.9992465972900391, z=-0.051316212862730026, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7789103984832764, y=0.8931596279144287, z=-0.07577405124902725, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7729551792144775, y=0.7924570441246033, z=-0.09275075048208237, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7478009462356567, y=0.7133104801177979, z=-0.11001545190811157, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8432216644287109, y=0.7762141227722168, z=-0.06041470915079117, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8558437824249268, y=0.6606903672218323, z=-0.09650056809186935, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8681219816207886, y=0.5851982831954956, z=-0.1243491843342781, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8841461539268494, y=0.5176063179969788, z=-0.14403745532035828, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.907482385635376, y=0.7760915756225586, z=-0.05749940127134323, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9327928423881531, y=0.6543840169906616, z=-0.08546913415193558, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.955353856086731, y=0.5677592754364014, z=-0.11032979935407639, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.979996383190155, y=0.4918859601020813, z=-0.12930180132389069, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9564367532730103, y=0.8103657364845276, z=-0.0590815432369709, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9863184690475464, y=0.7134561538696289, z=-0.09174177795648575, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0087902545928955, y=0.6663826107978821, z=-0.11009172350168228, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0297034978866577, y=0.6247467994689941, z=-0.12240402400493622, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9939600229263306, y=0.8668394684791565, z=-0.06414012610912323, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0137994289398193, y=0.8204390406608582, z=-0.09741926193237305, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.024155616760254, y=0.8054796457290649, z=-0.10710965096950531, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.032982587814331, y=0.7920117974281311, z=-0.11176696419715881, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8882578015327454, y=1.0533363819122314, z=8.588063451497874e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8160905838012695, y=1.0039997100830078, z=-0.05336364358663559, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7820624113082886, y=0.8924270272254944, z=-0.0773046538233757, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7726354002952576, y=0.7874889373779297, z=-0.09447323530912399, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7450876235961914, y=0.7067899703979492, z=-0.11174935102462769, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8431798815727234, y=0.7724611759185791, z=-0.05471627786755562, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8572354316711426, y=0.6506460309028625, z=-0.09162021428346634, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8711898326873779, y=0.571610689163208, z=-0.12044692039489746, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8882325291633606, y=0.5027927160263062, z=-0.1404748111963272, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9077283143997192, y=0.7728392481803894, z=-0.050906773656606674, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9346314072608948, y=0.6454082727432251, z=-0.07900284230709076, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9566636085510254, y=0.5552098155021667, z=-0.10424873977899551, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9805738925933838, y=0.4777790904045105, z=-0.12291056662797928, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9581389427185059, y=0.8072114586830139, z=-0.0526261068880558, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9918264746665955, y=0.704215407371521, z=-0.08584602922201157, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.015164852142334, y=0.6532484292984009, z=-0.10559068620204926, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.036816954612732, y=0.6096395254135132, z=-0.11861127614974976, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9967327117919922, y=0.8648290634155273, z=-0.05835928022861481, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.022927165031433, y=0.8254624009132385, z=-0.094009168446064, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0377988815307617, y=0.816925048828125, z=-0.10563334077596664, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0510388612747192, y=0.8101823925971985, z=-0.11090487241744995, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8922735452651978, y=1.0693832635879517, z=8.171739409590373e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8186105489730835, y=1.014772653579712, z=-0.05539283528923988, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7802050709724426, y=0.9042619466781616, z=-0.08126559108495712, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7706456184387207, y=0.7969616651535034, z=-0.10035470128059387, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7445205450057983, y=0.7113698124885559, z=-0.11759232729673386, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8458321690559387, y=0.7788428664207458, z=-0.05002874508500099, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.854844868183136, y=0.652676522731781, z=-0.08415352553129196, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8655779361724854, y=0.5721779465675354, z=-0.11090661585330963, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.880547821521759, y=0.5013548135757446, z=-0.1294388771057129, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9086968898773193, y=0.7770707607269287, z=-0.04415050894021988, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9294254183769226, y=0.6463919878005981, z=-0.07094267010688782, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9484270215034485, y=0.5559288263320923, z=-0.09440550208091736, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.970439076423645, y=0.47787949442863464, z=-0.11201932281255722, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9602438807487488, y=0.808133065700531, z=-0.044373322278261185, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9939929842948914, y=0.6989844441413879, z=-0.07418400794267654, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0169494152069092, y=0.6464107036590576, z=-0.0874103531241417, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0370023250579834, y=0.6025295257568359, z=-0.09523666650056839, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0031278133392334, y=0.859199583530426, z=-0.049407958984375, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.039165735244751, y=0.7879331111907959, z=-0.0757371112704277, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0656745433807373, y=0.7512340545654297, z=-0.08132511377334595, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.088723063468933, y=0.7198864817619324, z=-0.08310391008853912, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8806430101394653, y=1.085785150527954, z=7.860597293074534e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8136845827102661, y=1.0252759456634521, z=-0.05322696268558502, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7793499231338501, y=0.9095596075057983, z=-0.0777362585067749, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7687582969665527, y=0.8011847734451294, z=-0.09620800614356995, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7426518201828003, y=0.7136745452880859, z=-0.11319497972726822, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8459450602531433, y=0.7881967425346375, z=-0.048196688294410706, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8549212217330933, y=0.6595032811164856, z=-0.08258286863565445, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8640491962432861, y=0.5792142748832703, z=-0.10903395712375641, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8778634071350098, y=0.5076822638511658, z=-0.12742209434509277, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9093858003616333, y=0.7888368964195251, z=-0.04411361366510391, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9295931458473206, y=0.6549369692802429, z=-0.07134954631328583, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9476989507675171, y=0.5642374753952026, z=-0.09522337466478348, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9682236909866333, y=0.4867483675479889, z=-0.11317482590675354, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9621722102165222, y=0.8226934671401978, z=-0.04611637815833092, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9949519634246826, y=0.7141902446746826, z=-0.07711831480264664, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0172237157821655, y=0.6605641841888428, z=-0.09155379980802536, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0361922979354858, y=0.6147328019142151, z=-0.1001020297408104, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0065654516220093, y=0.8776078224182129, z=-0.05264333635568619, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0450471639633179, y=0.8042435646057129, z=-0.07993760704994202, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.072746992111206, y=0.7666740417480469, z=-0.08627086877822876, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0963878631591797, y=0.7339276075363159, z=-0.08869700878858566, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8664417266845703, y=1.0896668434143066, z=7.989232813088165e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.806778073310852, y=1.0303255319595337, z=-0.054297685623168945, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7744480967521667, y=0.9148977398872375, z=-0.08070362359285355, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7590130567550659, y=0.8065561652183533, z=-0.10103099048137665, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7317671775817871, y=0.7180997133255005, z=-0.12006437033414841, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8419378399848938, y=0.7876449823379517, z=-0.050578247755765915, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8518105149269104, y=0.6585628986358643, z=-0.08529756218194962, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.861656665802002, y=0.5774847865104675, z=-0.1126202791929245, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8767828345298767, y=0.5059608817100525, z=-0.13160750269889832, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.906213104724884, y=0.7886499762535095, z=-0.04566892609000206, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9298315048217773, y=0.6530396938323975, z=-0.07162045687437057, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9485975503921509, y=0.5626335144042969, z=-0.09423968195915222, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9706566333770752, y=0.4856199622154236, z=-0.11141495406627655, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9592779278755188, y=0.8244333267211914, z=-0.04681423678994179, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0007857084274292, y=0.7114225029945374, z=-0.07503627985715866, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.030272364616394, y=0.6521540284156799, z=-0.08843622356653214, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.056291103363037, y=0.6011530160903931, z=-0.09716006368398666, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0029338598251343, y=0.8825750350952148, z=-0.05273665487766266, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0534039735794067, y=0.8136229515075684, z=-0.07853260636329651, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.089136004447937, y=0.7745054960250854, z=-0.08473856002092361, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.1194182634353638, y=0.7388129234313965, z=-0.0872374102473259, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8522197008132935, y=1.0778758525848389, z=6.906614089530194e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7847656011581421, y=1.0202702283859253, z=-0.048181161284446716, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7433151006698608, y=0.9116858839988708, z=-0.0732506513595581, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7221607565879822, y=0.8082475066184998, z=-0.09334525465965271, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6941764950752258, y=0.7205154299736023, z=-0.11297402530908585, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.808089017868042, y=0.7827618718147278, z=-0.048854004591703415, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8071846961975098, y=0.6550265550613403, z=-0.0819091871380806, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8113341331481934, y=0.572528600692749, z=-0.10794491320848465, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8213963508605957, y=0.4990130364894867, z=-0.12687644362449646, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8724238276481628, y=0.7791106104850769, z=-0.047604743391275406, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8895933032035828, y=0.6431597471237183, z=-0.0739578902721405, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9032465219497681, y=0.5515478849411011, z=-0.09752188622951508, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9189924597740173, y=0.4684756100177765, z=-0.11598160117864609, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9279638528823853, y=0.810992419719696, z=-0.05165231600403786, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9675917625427246, y=0.6898936033248901, z=-0.08146585524082184, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9969732761383057, y=0.6153574585914612, z=-0.10087979584932327, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0213379859924316, y=0.5467804670333862, z=-0.11494029313325882, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9750599265098572, y=0.8671292066574097, z=-0.05936985835433006, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0304923057556152, y=0.7950962781906128, z=-0.08768554776906967, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.069104552268982, y=0.75348961353302, z=-0.09827029705047607, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0995005369186401, y=0.7130551934242249, z=-0.10496222972869873, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8397483825683594, y=1.0693848133087158, z=6.83425469105714e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7720308303833008, y=1.0038304328918457, z=-0.043195318430662155, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7270539402961731, y=0.8960660696029663, z=-0.06576426327228546, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7023356556892395, y=0.7958261966705322, z=-0.08433539420366287, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6694825291633606, y=0.7140608429908752, z=-0.10289251804351807, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7887318134307861, y=0.7658366560935974, z=-0.041417334228754044, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7840638756752014, y=0.6399006247520447, z=-0.07320570200681686, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7861192226409912, y=0.5616178512573242, z=-0.09883330762386322, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7916938066482544, y=0.49040287733078003, z=-0.11803636699914932, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.852671205997467, y=0.7660685181617737, z=-0.04362965747714043, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8635403513908386, y=0.6291911005973816, z=-0.0698758140206337, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.87378990650177, y=0.5403541326522827, z=-0.09478915482759476, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8862808346748352, y=0.45738962292671204, z=-0.11379136145114899, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9090152978897095, y=0.8018115162849426, z=-0.05097699537873268, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9421740770339966, y=0.6800390481948853, z=-0.08223486691713333, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.966759443283081, y=0.604271650314331, z=-0.10372097045183182, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9867329001426697, y=0.5326061248779297, z=-0.11911765486001968, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9579795598983765, y=0.8630654215812683, z=-0.06129830330610275, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9994685053825378, y=0.7992062568664551, z=-0.09197185933589935, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0229425430297852, y=0.7618792057037354, z=-0.10318765044212341, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0395392179489136, y=0.722839891910553, z=-0.11010508984327316, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.826374351978302, y=1.068299651145935, z=6.320560714812018e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7529543042182922, y=1.000948190689087, z=-0.04101627692580223, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7089137434959412, y=0.8863773941993713, z=-0.06081952899694443, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6862164735794067, y=0.7820677161216736, z=-0.07679611444473267, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.650589108467102, y=0.7028477787971497, z=-0.09320466220378876, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7709141373634338, y=0.7658494710922241, z=-0.03986240550875664, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7629764676094055, y=0.6369588971138, z=-0.07045964151620865, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7629001140594482, y=0.5560441017150879, z=-0.09438443928956985, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7665581107139587, y=0.482488751411438, z=-0.11238673329353333, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8343942165374756, y=0.7648231983184814, z=-0.0434926338493824, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8441965579986572, y=0.6241952776908875, z=-0.06964036822319031, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8539941310882568, y=0.5340812802314758, z=-0.09372661262750626, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.865122377872467, y=0.450996458530426, z=-0.11205706000328064, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8902535438537598, y=0.7976346015930176, z=-0.05212901532649994, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9193735122680664, y=0.6695717573165894, z=-0.08444253355264664, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9439787864685059, y=0.590224027633667, z=-0.10625515133142471, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9633342623710632, y=0.5168213844299316, z=-0.12131429463624954, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9392622709274292, y=0.8536663055419922, z=-0.06345967203378677, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9803541302680969, y=0.7723817229270935, z=-0.09418036043643951, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0078331232070923, y=0.7288627028465271, z=-0.10517935454845428, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0274691581726074, y=0.6861982345581055, z=-0.11201412230730057, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8172107338905334, y=1.0691354274749756, z=6.238212790776743e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.74245685338974, y=1.002039909362793, z=-0.04004193842411041, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6992846727371216, y=0.8868345618247986, z=-0.05956343188881874, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6779028177261353, y=0.7832179665565491, z=-0.07513715326786041, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6417426466941833, y=0.7079485654830933, z=-0.09193794429302216, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.760017991065979, y=0.7693380117416382, z=-0.0449998714029789, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7514255046844482, y=0.6376899480819702, z=-0.07668416202068329, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7502160668373108, y=0.5556265711784363, z=-0.10047417134046555, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7528156042098999, y=0.48096752166748047, z=-0.11838872730731964, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8243547677993774, y=0.7681814432144165, z=-0.04990395903587341, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8337361812591553, y=0.6256816387176514, z=-0.0782466009259224, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8405972123146057, y=0.5353608131408691, z=-0.10365133732557297, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8479995131492615, y=0.4527941644191742, z=-0.1228344514966011, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8807467222213745, y=0.8006137013435364, z=-0.059204258024692535, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9069259762763977, y=0.6702556610107422, z=-0.09389889240264893, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9283727407455444, y=0.5881434082984924, z=-0.1174025759100914, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9455519914627075, y=0.5115047693252563, z=-0.1335727721452713, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9288456439971924, y=0.8558771014213562, z=-0.07078824937343597, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9705078601837158, y=0.7700096368789673, z=-0.10434455424547195, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.002549648284912, y=0.7204368710517883, z=-0.11741910129785538, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.028725028038025, y=0.6712364554405212, z=-0.12566877901554108, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8050520420074463, y=1.0789622068405151, z=5.916900249758328e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7314435839653015, y=1.0132454633712769, z=-0.03934215381741524, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6910048127174377, y=0.8946513533592224, z=-0.05709722638130188, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6723586320877075, y=0.7907832860946655, z=-0.07107236236333847, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6368857026100159, y=0.7180612087249756, z=-0.08631471544504166, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7535056471824646, y=0.7811752557754517, z=-0.04427839070558548, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7448436617851257, y=0.6483507752418518, z=-0.07565805315971375, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.744239330291748, y=0.5656780004501343, z=-0.0989447832107544, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.747166633605957, y=0.4907616078853607, z=-0.1167614609003067, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8184062838554382, y=0.7794052362442017, z=-0.04982482269406319, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8265848159790039, y=0.6368898749351501, z=-0.0781024694442749, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8330680131912231, y=0.5453028678894043, z=-0.10394307971000671, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8399338126182556, y=0.4621707499027252, z=-0.12353596836328506, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8746463060379028, y=0.8122541308403015, z=-0.059775836765766144, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9011951684951782, y=0.6832525134086609, z=-0.09528083354234695, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9232333898544312, y=0.6011357307434082, z=-0.12030979990959167, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.940534234046936, y=0.524103045463562, z=-0.13749809563159943, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9223429560661316, y=0.8686224818229675, z=-0.07196055352687836, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9661670327186584, y=0.789274275302887, z=-0.10762528330087662, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9991415143013, y=0.7393949031829834, z=-0.12312474846839905, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0261021852493286, y=0.6886919736862183, z=-0.13298483192920685, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8058529496192932, y=1.0915415287017822, z=5.849490207765484e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7313388586044312, y=1.0288046598434448, z=-0.04062836617231369, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6873652935028076, y=0.9123296141624451, z=-0.059326063841581345, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6640145182609558, y=0.8080085515975952, z=-0.07436896860599518, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6261903047561646, y=0.7319402694702148, z=-0.08996273577213287, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7452885508537292, y=0.7939327359199524, z=-0.042300745844841, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7318358421325684, y=0.6601294875144958, z=-0.07284145057201385, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7279194593429565, y=0.5772314667701721, z=-0.0951247438788414, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7284317016601562, y=0.5015445351600647, z=-0.11221989244222641, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8096436262130737, y=0.7888129949569702, z=-0.046661607921123505, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8138598799705505, y=0.6439545154571533, z=-0.07416003197431564, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8209489583969116, y=0.5516953468322754, z=-0.09882567822933197, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8293358683586121, y=0.46749454736709595, z=-0.11744257062673569, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8675482869148254, y=0.8188523650169373, z=-0.05590059608221054, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8916407823562622, y=0.689574122428894, z=-0.09014267474412918, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9119940400123596, y=0.607338547706604, z=-0.11403245478868484, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9283393025398254, y=0.5305396914482117, z=-0.13026989996433258, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9188916087150574, y=0.8721932172775269, z=-0.06765526533126831, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9629076719284058, y=0.7894570231437683, z=-0.10041461884975433, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9950166940689087, y=0.7361065149307251, z=-0.11485178023576736, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0214452743530273, y=0.6814079284667969, z=-0.12432705610990524, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8103215098381042, y=1.0989773273468018, z=6.116923714216682e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7290584444999695, y=1.0404587984085083, z=-0.04495391994714737, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.680526077747345, y=0.9287697076797485, z=-0.06715604662895203, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6553763151168823, y=0.822742760181427, z=-0.08499029278755188, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6153388023376465, y=0.7432214021682739, z=-0.10356400907039642, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7375918626785278, y=0.8088136315345764, z=-0.052320413291454315, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7228172421455383, y=0.6722220778465271, z=-0.0866277813911438, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7174772024154663, y=0.5881930589675903, z=-0.11071977019309998, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7165822386741638, y=0.5106159448623657, z=-0.1289285272359848, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8026930093765259, y=0.8038908243179321, z=-0.056161824613809586, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8046571612358093, y=0.6583702564239502, z=-0.0882745161652565, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8093977570533752, y=0.5652714967727661, z=-0.11531714349985123, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8160634636878967, y=0.4787482023239136, z=-0.13571210205554962, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.861372709274292, y=0.8327465057373047, z=-0.06490012258291245, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8841369152069092, y=0.7011801600456238, z=-0.10404230654239655, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9039707183837891, y=0.617780864238739, z=-0.12989947199821472, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9197996258735657, y=0.5387082099914551, z=-0.1471925973892212, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.913567841053009, y=0.8840137720108032, z=-0.07621726393699646, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9568952322006226, y=0.7979156374931335, z=-0.11349759250879288, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9888414144515991, y=0.7424499988555908, z=-0.1301046460866928, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0152156352996826, y=0.6852704286575317, z=-0.14097632467746735, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8104894161224365, y=1.1028637886047363, z=6.947024644432531e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7279614806175232, y=1.0496766567230225, z=-0.046076979488134384, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6788233518600464, y=0.9419305920600891, z=-0.06986333429813385, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6523662805557251, y=0.8371159434318542, z=-0.08874380588531494, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6117534041404724, y=0.7544891238212585, z=-0.108446404337883, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7330015301704407, y=0.8212107419967651, z=-0.058994680643081665, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7177391648292542, y=0.6835111975669861, z=-0.09451323002576828, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.712272047996521, y=0.5981956720352173, z=-0.11889204382896423, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7113484144210815, y=0.5209317207336426, z=-0.137105330824852, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8001617789268494, y=0.8165181875228882, z=-0.06331916153430939, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8014549612998962, y=0.6690348386764526, z=-0.09576158225536346, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8049020171165466, y=0.5743805170059204, z=-0.12275296449661255, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8093124628067017, y=0.48895084857940674, z=-0.14322680234909058, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8600997924804688, y=0.8462076187133789, z=-0.07223127782344818, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8819198608398438, y=0.713096022605896, z=-0.11200150102376938, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9017543196678162, y=0.6271082162857056, z=-0.13868768513202667, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9166378974914551, y=0.5460948348045349, z=-0.1568061262369156, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9133532643318176, y=0.8982410430908203, z=-0.08347628265619278, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9578721523284912, y=0.8123358488082886, z=-0.12261264771223068, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9896423816680908, y=0.7559001445770264, z=-0.14019647240638733, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=1.0145092010498047, y=0.6978957653045654, z=-0.15146991610527039, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8145338892936707, y=1.1025900840759277, z=7.383421234408161e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7307421565055847, y=1.0499299764633179, z=-0.04604586586356163, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6803548336029053, y=0.9418970942497253, z=-0.06965166330337524, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6532373428344727, y=0.8366756439208984, z=-0.08826320618391037, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.6138242483139038, y=0.7519106268882751, z=-0.10771851986646652, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.733771026134491, y=0.8222689628601074, z=-0.05895453691482544, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7191052436828613, y=0.6845411658287048, z=-0.09435725212097168, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.713367760181427, y=0.5985569953918457, z=-0.11907990276813507, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7126578092575073, y=0.519740879535675, z=-0.13762174546718597, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8018864989280701, y=0.8165311217308044, z=-0.06306632608175278, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8028116822242737, y=0.6709023714065552, z=-0.09531458467245102, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8057845234870911, y=0.5755844116210938, z=-0.12266920506954193, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8099527359008789, y=0.4886799454689026, z=-0.14345099031925201, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8621808290481567, y=0.8451601266860962, z=-0.07163787633180618, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8845024108886719, y=0.7122055888175964, z=-0.1109078973531723, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9021311402320862, y=0.6260890364646912, z=-0.1374068707227707, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9145679473876953, y=0.5443709492683411, z=-0.15552963316440582, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9151989817619324, y=0.8958097696304321, z=-0.08250630646944046, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9599981307983398, y=0.8097109198570251, z=-0.12125097960233688, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.990104079246521, y=0.7519949674606323, z=-0.13848820328712463, visibility=None, presence=None, name=None)
# ...
# lm : NormalizedLandmark(x=0.7709751725196838, y=0.3891834020614624, z=-0.0714733898639679, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8220247030258179, y=0.5582194924354553, z=-0.018590208142995834, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8240275979042053, y=0.45101433992385864, z=-0.03606044128537178, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8279320001602173, y=0.3809584677219391, z=-0.05414509400725365, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8323450684547424, y=0.3171460032463074, z=-0.0686030387878418, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8657733798027039, y=0.565757155418396, z=-0.025622978806495667, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8801270127296448, y=0.46571025252342224, z=-0.049901627004146576, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8908514976501465, y=0.40291786193847656, z=-0.06703709065914154, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8986246585845947, y=0.3451152443885803, z=-0.07866162061691284, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.908390998840332, y=0.5944150686264038, z=-0.03540545701980591, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9399967193603516, y=0.5219003558158875, z=-0.058760371059179306, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9637187123298645, y=0.4750047028064728, z=-0.06904111057519913, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.983772337436676, y=0.4301975965499878, z=-0.07568936794996262, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8560425639152527, y=0.8464279174804688, z=-3.1486396778745984e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7900787591934204, y=0.7956267595291138, z=-0.020372720435261726, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7444261908531189, y=0.7074663043022156, z=-0.030896825715899467, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7211048007011414, y=0.6298271417617798, z=-0.04345935583114624, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7041943073272705, y=0.5642970204353333, z=-0.05178613215684891, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7786582112312317, y=0.6054210662841797, z=0.008444753475487232, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.768703281879425, y=0.5084001421928406, z=-0.02616121619939804, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7719826698303223, y=0.5334937572479248, z=-0.053632378578186035, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7788363099098206, y=0.5793067216873169, z=-0.06704303622245789, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8215546011924744, y=0.5938299298286438, z=0.002703234786167741, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8213763236999512, y=0.4953007996082306, z=-0.03509419038891792, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8242816925048828, y=0.5129150748252869, z=-0.06077998876571655, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8259791731834412, y=0.5457150340080261, z=-0.06931334733963013, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8632375001907349, y=0.5976729393005371, z=-0.010017327964305878, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8733136057853699, y=0.5024111270904541, z=-0.0379360057413578, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8831926584243774, y=0.4628962576389313, z=-0.053092580288648605, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8910252451896667, y=0.43305206298828125, z=-0.05811015143990517, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9032059907913208, y=0.6175569891929626, z=-0.025057930499315262, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9257342219352722, y=0.5479632019996643, z=-0.04213706776499748, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9435948729515076, y=0.5052446722984314, z=-0.04916944354772568, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9586689472198486, y=0.4651525616645813, z=-0.05155821889638901, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8529288172721863, y=0.8719668388366699, z=-6.457284484895354e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7907822728157043, y=0.8203295469284058, z=-0.026454517617821693, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7439787983894348, y=0.7304977178573608, z=-0.04084478318691254, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7238764762878418, y=0.6569709777832031, z=-0.05809972807765007, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7293025255203247, y=0.5922825336456299, z=-0.06987083703279495, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7732868194580078, y=0.634270191192627, z=-0.001991261960938573, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7638719081878662, y=0.5607502460479736, z=-0.04299658536911011, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7643177509307861, y=0.6260254383087158, z=-0.07070746272802353, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7686012983322144, y=0.6834196448326111, z=-0.08274415880441666, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8182403445243835, y=0.6212834119796753, z=-0.005486471112817526, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8139763474464417, y=0.5346325635910034, z=-0.04465961456298828, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.808352530002594, y=0.6132772564888, z=-0.060258813202381134, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8083102703094482, y=0.671174168586731, z=-0.061734698712825775, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8626896739006042, y=0.6240614652633667, z=-0.016293808817863464, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8687947392463684, y=0.5291159749031067, z=-0.052838511765003204, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8591380715370178, y=0.6012755036354065, z=-0.05053446441888809, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8555241823196411, y=0.664526104927063, z=-0.03847276046872139, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9046792984008789, y=0.6409342288970947, z=-0.030193820595741272, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9172924757003784, y=0.561419665813446, z=-0.052746038883924484, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9084331393241882, y=0.5927134156227112, z=-0.048979416489601135, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9028496146202087, y=0.6338576078414917, z=-0.03933606296777725, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8607617616653442, y=0.9084954261779785, z=-7.238861030600674e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7944003343582153, y=0.8570405840873718, z=-0.025430556386709213, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7410659790039062, y=0.7745607495307922, z=-0.03763166815042496, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7212068438529968, y=0.6957696080207825, z=-0.052413519471883774, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7348297238349915, y=0.6351340413093567, z=-0.059933073818683624, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7676795721054077, y=0.6831344962120056, z=0.006921837106347084, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7681702971458435, y=0.6105306148529053, z=-0.0341823510825634, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7744044661521912, y=0.6881758570671082, z=-0.057444214820861816, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.774828314781189, y=0.7337810397148132, z=-0.06582022458314896, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8105475306510925, y=0.6726635694503784, z=0.00480306101962924, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.81083744764328, y=0.6005669832229614, z=-0.03466362878680229, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8132269382476807, y=0.6902828812599182, z=-0.04499339312314987, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8090575933456421, y=0.7283315062522888, z=-0.041896380484104156, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8555479049682617, y=0.6704992651939392, z=-0.005577922333031893, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8576927781105042, y=0.5942561030387878, z=-0.04311976581811905, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8558862805366516, y=0.6781087517738342, z=-0.03221432492136955, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8516722917556763, y=0.7232477068901062, z=-0.013593025505542755, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8977445363998413, y=0.6784651279449463, z=-0.018847614526748657, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8979701399803162, y=0.6127240657806396, z=-0.036920253187417984, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8912132382392883, y=0.6667783856391907, z=-0.02412346377968788, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8872715830802917, y=0.7041855454444885, z=-0.007998297922313213, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8612107634544373, y=0.9525974988937378, z=-7.194755653472384e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8006649613380432, y=0.9076487421989441, z=-0.028246015310287476, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7481281161308289, y=0.8306462168693542, z=-0.0441320426762104, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7278529405593872, y=0.7552825808525085, z=-0.06200559809803963, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7467358112335205, y=0.6899234652519226, z=-0.0740644782781601, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7809239029884338, y=0.73016756772995, z=-0.00027677082107402384, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7805218696594238, y=0.6860731840133667, z=-0.047643888741731644, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7896434664726257, y=0.7602497339248657, z=-0.07438164949417114, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7952486276626587, y=0.8125205636024475, z=-0.08339200168848038, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8208471536636353, y=0.7208753228187561, z=-0.002499150577932596, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8173338770866394, y=0.6637621521949768, z=-0.05222843587398529, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8251749873161316, y=0.7560043334960938, z=-0.06672460585832596, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8279027938842773, y=0.8026358485221863, z=-0.06296748667955399, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8631070852279663, y=0.7229713201522827, z=-0.012813137844204903, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8625530004501343, y=0.6657581329345703, z=-0.06142423674464226, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8625748157501221, y=0.7527341246604919, z=-0.054720137268304825, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.861138641834259, y=0.7995494604110718, z=-0.034604866057634354, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9035494327545166, y=0.7365663051605225, z=-0.02542591653764248, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9035833477973938, y=0.6775165796279907, z=-0.05184212699532509, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.89995938539505, y=0.7294477224349976, z=-0.04197274520993233, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8972763419151306, y=0.765175998210907, z=-0.024973072111606598, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.869020938873291, y=0.9935494065284729, z=-8.140642648868379e-07, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8059592247009277, y=0.9557343125343323, z=-0.0162828266620636, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7611119747161865, y=0.8835227489471436, z=-0.026722677052021027, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7460519075393677, y=0.8153750896453857, z=-0.039456069469451904, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7612346410751343, y=0.7702293395996094, z=-0.0486435741186142, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7927221059799194, y=0.7979071736335754, z=-0.001459539053030312, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.7866396307945251, y=0.7620030641555786, z=-0.03362429887056351, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.794858992099762, y=0.8326808214187622, z=-0.05352041497826576, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8025367259979248, y=0.8847935199737549, z=-0.06114289164543152, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.835059404373169, y=0.7905240654945374, z=-0.005853802897036076, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8309224843978882, y=0.7725322842597961, z=-0.03830299526453018, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8394244909286499, y=0.8483830690383911, z=-0.04840433970093727, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8445601463317871, y=0.8976126909255981, z=-0.046887703239917755, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8765614628791809, y=0.7914304733276367, z=-0.01505665760487318, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8724636435508728, y=0.7755090594291687, z=-0.04669378325343132, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8764618039131165, y=0.8464179039001465, z=-0.03983721509575844, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.8786967992782593, y=0.8935121893882751, z=-0.0258623193949461, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9157842397689819, y=0.8023228049278259, z=-0.025829603895545006, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.911464512348175, y=0.7771201729774475, z=-0.043617963790893555, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9088252186775208, y=0.8352371454238892, z=-0.032727066427469254, visibility=None, presence=None, name=None)
# lm : NormalizedLandmark(x=0.9086909294128418, y=0.8761908411979675, z=-0.018305962905287743, visibility=None, presence=None, name=None)

# %%
import random

# 선택지 및 매핑
choices = {0: "가위", 1: "바위", 2: "보"}

print("=== 가위바위보 게임 ===")
user_input = int(input("가위(0), 바위(1), 보(2) 중 하나를 선택하세요: "))

if user_input not in [0, 1, 2]:
    print("잘못된 입력입니다.")
else:
    # 1. 컴퓨터의 무작위 선택
    computer_choice = random.randint(0, 2)
    
    print(f"사용자: {choices[user_input]} vs 컴퓨터: {choices[computer_choice]}")
    
    # 2. 승패 판정 (모듈로 연산 활용)
    result = (user_input - computer_choice) % 3
    
    if result == 0:
        print("결과: 비겼습니다!")
    elif result == 1:
        print("결과: 이겼습니다!")
    else:
        print("결과: 졌습니다!")
# Out:
# === 가위바위보 게임 ===
# 사용자: 바위 vs 컴퓨터: 가위
# 결과: 이겼습니다!

# %%
# OpenCV 라이브러리: 비디오 프레임 처리 및 화면 출력을 담당
import cv2

# MediaPipe 라이브러리: 손 관절(Landmark) 추론 및 컴퓨터 비전 기능 제공
import mediapipe as mp

# random 라이브러리: 컴퓨터의 가위/바위/보 무작위 선택에 사용
import random

# time 라이브러리: MediaPipe Tasks API 입력에 필요한 밀리초 타임스탬프 계산
import time

# ==============================================================================
# 1. MediaPipe Tasks API 필수 모듈 및 설정 로드
# ==============================================================================
# BaseOptions: 모델 파일 경로(.task) 및 CPU/GPU 디바이스 지정 옵션
BaseOptions = mp.tasks.BaseOptions

# HandLandmarker: 21개 손 관절 좌표를 추론하는 메인 클래스
HandLandmarker = mp.tasks.vision.HandLandmarker

# HandLandmarkerOptions: 추론 신뢰도, 감지할 손 개수, 실행 모드를 세팅하는 클래스
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions

# VisionRunningMode: 입력 형태 설정 (IMAGE: 이미지, VIDEO: 비디오 파일, LIVE_STREAM: 비동기 스트림)
VisionRunningMode = mp.tasks.vision.RunningMode

# 손 관절 뼈대를 이어줄 21개 랜드마크 인덱스 쌍 정의 (시각화 목적)
HAND_CONNECTIONS = [
    (0, 1), (1, 2), (2, 3), (3, 4),        # 엄지손가락 마디 연결선
    (0, 5), (5, 6), (6, 7), (7, 8),        # 검지손가락 마디 연결선
    (5, 9), (9, 10), (10, 11), (11, 12),   # 중지손가락 마디 연결선
    (9, 13), (13, 14), (14, 15), (15, 16), # 약지손가락 마디 연결선
    (13, 17), (0, 17), (17, 18), (18, 19), (19, 20) # 새끼손가락 마디 연결선
]

# ==============================================================================
# 2. 손지형(가위, 바위, 보) 판별 함수
# ==============================================================================
# 21개 관절 좌표(landmarks)를 전달받아 가위/바위/보 또는 알 수 없음 문자열을 반환하는 함수
def classify_rps(landmarks):
    # 검지 뿌리(5)와 새끼 뿌리(17)의 x좌표 위치를 비교하여 손바닥이 바라보는 방향 판별
    # 검지 뿌리가 오른쪽에 있으면 오른손, 왼쪽에 있으면 왼손 기준 적용
    if landmarks[5].x > landmarks[17].x:
        # 오른손 기준: 엄지 끝(4)의 x좌표가 엄지 마디(3)보다 오른쪽(더 큼)에 있으면 펴진 상태
        thumb_open = landmarks[4].x > landmarks[3].x
    else:
        # 왼손 기준: 엄지 끝(4)의 x좌표가 엄지 마디(3)보다 왼쪽(더 작음)에 있으면 펴진 상태
        thumb_open = landmarks[4].x < landmarks[3].x

    # 나머지 4개 손가락은 y축 좌표 비교 (화면 상단이 0, 하단이 1이므로 y값이 작을수록 위로 펴짐)
    # 검지 손가락 끝(8)이 중간 마디(6)보다 위(y값이 작음)에 있는지 확인
    index_open = landmarks[8].y < landmarks[6].y
    
    # 중지 손가락 끝(12)이 중간 마디(10)보다 위에 있는지 확인
    middle_open = landmarks[12].y < landmarks[10].y
    
    # 약지 손가락 끝(16)이 중간 마디(14)보다 위에 있는지 확인
    ring_open = landmarks[16].y < landmarks[14].y
    
    # 새끼 손가락 끝(20)이 중간 마디(18)보다 위에 있는지 확인
    pinky_open = landmarks[20].y < landmarks[18].y

    # 가위 조건 1: (엄지+검지)가 펴지고 중지, 약지, 새끼는 굽혀진 경우 (권총 모양)
    scissors_thumb_index = thumb_open and index_open and (not middle_open) and (not ring_open) and (not pinky_open)
    
    # 가위 조건 2: (검지+중지)가 펴지고 엄지, 약지, 새끼는 굽혀진 경우 (V 자 모양)
    scissors_index_middle = (not thumb_open) and index_open and middle_open and (not ring_open) and (not pinky_open)

    # 가위 조건 1 또는 2 중 하나라도 만족 시 "가위" 반환
    if scissors_thumb_index or scissors_index_middle:
        return "가위"
    
    # 보 조건: 엄지를 포함한 5개 손가락이 모두 펴진 경우 "보" 반환
    elif thumb_open and index_open and middle_open and ring_open and pinky_open:
        return "보"
    
    # 바위 조건: 엄지를 포함한 5개 손가락이 모두 굽혀진 경우 "바위" 반환
    elif (not thumb_open) and (not index_open) and (not middle_open) and (not ring_open) and (not pinky_open):
        return "바위"
    
    # 위 조건들에 해당하지 않는 부정확한 손짓일 경우 "알 수 없음" 반환
    else:
        return "알 수 없음"

# ==============================================================================
# 3. 메인 가위바위보 실행 및 UI 설정
# ==============================================================================
# MediaPipe HandLandmarker 모델 파라미터 및 인스턴스 옵션 구성
options = HandLandmarkerOptions(
    # 로컬 경로에 저장된 손 인식 모델 파일(.task) 지정
    base_options=BaseOptions(model_asset_path='hand_landmarker.task'),
    # 웹캠 비디오 프레임 스트림 처리를 위한 VIDEO 모드 선택
    running_mode=VisionRunningMode.VIDEO,
    # 추론할 최대 손 개수 (1개로 제한하여 오작동 방지)
    num_hands=1,
    # 최초 손 탐지 신뢰도 임계값 (50% 이상)
    min_hand_detection_confidence=0.5,
    # 프레임 간 손 추적 신뢰도 임계값 (50% 이상)
    min_tracking_confidence=0.5
)

# 0번 인덱스의 기본 웹캠 디바이스 연결
cap = cv2.VideoCapture(0)

# 가위바위보 게임에서 사용할 무작위 선택 리스트
choices = ["가위", "바위", "보"]
# choices = ["Scissor", "Rock", "Paper"]

# 컴퓨터가 선택한 낸 값 저장 변수 초기화
computer_choice = None

# 플레이어가 선택한 낸 값 저장 변수 초기화
user_choice = None

# 화면에 표시될 게임 결과 텍스트 초기화
game_result = "Space키를 눌러 가위바위보 시작!"

# 사용자 누적 점수 변수 초기화
score_user = 0

# 컴퓨터 누적 점수 변수 초기화
score_computer = 0

# HandLandmarker 인스턴스를 안전하게 생성하고 자원을 관리하는 with 블록 시작
with HandLandmarker.create_from_options(options) as landmarker:
    # 카메라 장치가 정상적으로 열려 있는 동안 지속 반복
    while cap.isOpened():
        # 카메라로부터 프레임 1개를 읽어옴 (ret: 성공여부, frame: BGR 이미지)
        ret, frame = cap.read()
        
        # 프레임을 읽어오지 못했으면(카메라 연결 끊김 등) 반복문 탈출
        if not ret:
            break

        # 사용자가 거울처럼 보게 하기 위해 좌우 반전 처리
        frame = cv2.flip(frame, 1)
        
        # 화면에 관절을 그리기 위해 프레임의 높이(h)와 너비(w) 추출
        h, w, _ = frame.shape
        
        # OpenCV의 BGR 색상 채널을 MediaPipe용 RGB 색상 채널로 변환
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # NumPy 이미지 배열을 MediaPipe 전용 Image 객체로 전환
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        
        # VIDEO 모드에 필수적으로 필요한 밀리초(ms) 단위의 타임스탬프 계산
        frame_timestamp_ms = int(time.time() * 1000)
        
        # MediaPipe 모델에 프레임과 타임스탬프를 전달하여 손 관절 추론 수행
        result = landmarker.detect_for_video(mp_image, frame_timestamp_ms)

        # 손 감지가 되지 않았을 때의 기본 상태 텍스트
        current_hand_gesture = "손을 올려주세요"

        # 손 관절 추론 결과가 존재할 경우
        if result.hand_landmarks:
            # 감지된 손 개수만큼 반복 (num_hands=1이므로 1회 실행)
            for hand_landmarks in result.hand_landmarks:
                # 21개 랜드마크의 화면 픽셀 좌표를 담을 리스트
                pixel_coords = []
                
                # 랜드마크 21개 좌표를 순회하며 픽셀 위치 계산
                for lm in hand_landmarks:
                    # 정규화된 0.0~1.0 좌표를 실제 화면 해상도 픽셀 좌표로 변환
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    pixel_coords.append((cx, cy))
                    
                    # 관절 위치에 초록색 원 그리기
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 0), -1)

                # 연결선 정의 배열(HAND_CONNECTIONS)에 따라 파란색 뼈대 그리기
                for start_idx, end_idx in HAND_CONNECTIONS:
                    cv2.line(frame, pixel_coords[start_idx], pixel_coords[end_idx], (255, 0, 0), 2)

                # 현재 캡처된 손 좌표를 분류 함수로 전달해 가위/바위/보 판단
                current_hand_gesture = classify_rps(hand_landmarks)

        # ======================================================================
        # 4. 게임 화면 UI 및 오버레이 텍스트 출력
        # ======================================================================
        # 상단 누적 스코어판 출력 (흰색)
        cv2.putText(frame, f"Score - You: {score_user} | Com: {score_computer}", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
        
        # 현재 카메라에 인식 중인 손 모양 텍스트 출력 (노란색)
        cv2.putText(frame, f"Detected Hand: {current_hand_gesture}", (20, 80),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        
        # 승패 및 안내 문구 출력 (초록색)
        cv2.putText(frame, f"Result: {game_result}", (20, 130),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

        # 컴퓨터의 선택이 존재할 경우 컴퓨터 선택값 출력 (연보라색)
        if computer_choice:
            cv2.putText(frame, f"Com Choice: {computer_choice}", (20, 170),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (200, 200, 250), 2)

        # 하단 조작법 안내 문구 출력 (회색)
        cv2.putText(frame, "Press 'Space' to Play / 'q' or ESC to Exit", (20, h - 20),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (180, 180, 180), 1)

        # 완성된 이미지 프레임을 창에 표시
        cv2.imshow("Rock Paper Scissors Game", frame)

        # 5밀리초 동안 키보드 입력 대기
        key = cv2.waitKey(5) & 0xFF
        
        # 스페이스바(ASCII 32) 입력 시 가위바위보 승패 판정 실행
        if key == 32:
            # 인식된 손 모양이 가위, 바위, 보 중 하나일 때만 게임 진행
            if current_hand_gesture in choices:
                # 사용자의 현재 손 모양 저장
                user_choice = current_hand_gesture
                
                # 컴퓨터의 선택 무작위 추출
                computer_choice = random.choice(choices)

                # 사용자 선택과 컴퓨터 선택이 같은 경우 (무승부)
                if user_choice == computer_choice:
                    game_result = f"Draw! (You: {user_choice} vs Com: {computer_choice})"
                
                # 사용자가 이기는 경우 (가위>보, 바위>가위, 보>바위)
                elif (user_choice == "가위" and computer_choice == "보") or \
                     (user_choice == "바위" and computer_choice == "가위") or \
                     (user_choice == "보" and computer_choice == "바위"):
                    game_result = f"You Win! (You: {user_choice} vs Com: {computer_choice})"
                    score_user += 1 # 사용자 점수 1점 추가
                
                # 컴퓨터가 이기는 경우
                else:
                    game_result = f"You Lose! (You: {user_choice} vs Com: {computer_choice})"
                    score_computer += 1 # 컴퓨터 점수 1점 추가
            
            # 인식 상태가 "알 수 없음"이거나 손을 올리지 않은 경우
            else:
                game_result = "Hand position unclear! Try again."

        # 'q' 키 또는 ESC(ASCII 27) 키 입력 시 게임 루프 종료
        elif key == 27 or key == ord('q'):
            break

# ==============================================================================
# 5. 메인 루프 종료 후 자원 해제
# ==============================================================================
# OpenCv 카메라 비디오 스트림 연결 해제
cap.release()

# 모든 OpenCV 그래픽 창 닫기
cv2.destroyAllWindows()

# %%
# OpenCV 라이브러리: 비디오 프레임 처리 및 화면 출력을 담당
import cv2

# MediaPipe 라이브러리: 손 관절(Landmark) 추론 및 컴퓨터 비전 기능 제공
import mediapipe as mp

# time 라이브러리: 1초 대기 및 쿨타임 시간 측정을 위해 사용
import time

# ==============================================================================
# 1. MediaPipe Tasks API 필수 모듈 및 설정 로드
# ==============================================================================
BaseOptions = mp.tasks.BaseOptions
HandLandmarker = mp.tasks.vision.HandLandmarker
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

HAND_CONNECTIONS = [
    (0, 1), (1, 2), (2, 3), (3, 4),        # 엄지손가락 마디 연결선
    (0, 5), (5, 6), (6, 7), (7, 8),        # 검지손가락 마디 연결선
    (5, 9), (9, 10), (10, 11), (11, 12),   # 중지손가락 마디 연결선
    (9, 13), (13, 14), (14, 15), (15, 16), # 약지손가락 마디 연결선
    (13, 17), (0, 17), (17, 18), (18, 19), (19, 20) # 새끼손가락 마디 연결선
]

# ==============================================================================
# 2. 손지형(가위, 바위, 보) 판별 함수
# ==============================================================================
def classify_rps(landmarks):
    if landmarks[5].x > landmarks[17].x:
        thumb_open = landmarks[4].x > landmarks[3].x
    else:
        thumb_open = landmarks[4].x < landmarks[3].x

    index_open = landmarks[8].y < landmarks[6].y
    middle_open = landmarks[12].y < landmarks[10].y
    ring_open = landmarks[16].y < landmarks[14].y
    pinky_open = landmarks[20].y < landmarks[18].y

    scissors_thumb_index = thumb_open and index_open and (not middle_open) and (not ring_open) and (not pinky_open)
    scissors_index_middle = (not thumb_open) and index_open and middle_open and (not ring_open) and (not pinky_open)
    scissors_index_middle2 = (not thumb_open) and (not index_open) and (not middle_open) and ring_open and pinky_open

    if scissors_thumb_index or scissors_index_middle or scissors_index_middle2:
        return "Scissors"
    elif thumb_open and index_open and middle_open and ring_open and pinky_open:
        return "Paper"
    elif (not thumb_open) and (not index_open) and (not middle_open) and (not ring_open) and (not pinky_open):
        return "Rock"
    else:
        return "Unknown"

# ==============================================================================
# 3. 메인 가위바위보 실행 및 UI 설정
# ==============================================================================
options = HandLandmarkerOptions(
    base_options=BaseOptions(model_asset_path='hand_landmarker.task'),
    running_mode=VisionRunningMode.VIDEO,
    num_hands=2,
    min_hand_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

cap = cv2.VideoCapture(0)

choices = ["Scissors", "Rock", "Paper"]

score_left = 0
score_right = 0
game_result = "Show 2 hands to start!"

# 타이머 및 상태 관련 변수
both_hands_start_time = None  # 두 손이 동시에 감지되기 시작한 시각
last_game_time = 0            # 마지막으로 게임 결과가 나온 시각 (쿨타임 제어)
COOLDOWN_TIME = 3.0           # 판정 후 다음 게임까지 대기하는 시간 (초)

with HandLandmarker.create_from_options(options) as landmarker:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        h, w, _ = frame.shape
        current_time = time.time()
        
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        frame_timestamp_ms = int(current_time * 1000)
        
        result = landmarker.detect_for_video(mp_image, frame_timestamp_ms)

        detected_gestures = {"Left": "None", "Right": "None"}

        if result.hand_landmarks and result.handedness:
            for idx, hand_landmarks in enumerate(result.hand_landmarks):
                hand_label = result.handedness[idx][0].category_name
                
                pixel_coords = []
                for lm in hand_landmarks:
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    pixel_coords.append((cx, cy))
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 0), -1)

                for start_idx, end_idx in HAND_CONNECTIONS:
                    cv2.line(frame, pixel_coords[start_idx], pixel_coords[end_idx], (255, 0, 0), 2)

                gesture = classify_rps(hand_landmarks)
                detected_gestures[hand_label] = gesture

                wrist_x, wrist_y = pixel_coords[0]
                cv2.putText(frame, f"{hand_label}: {gesture}", (wrist_x - 30, wrist_y + 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)

        # ======================================================================
        # 4. 자동 타이머 및 게임 승패 로직
        # ======================================================================
        left_choice = detected_gestures["Left"]
        right_choice = detected_gestures["Right"]

        # 두 손 모두 정상 인식(가위/바위/보 중 하나) 되었고, 쿨타임이 지난 경우
        if left_choice in choices and right_choice in choices:
            if current_time - last_game_time > COOLDOWN_TIME:
                if both_hands_start_time is None:
                    both_hands_start_time = current_time  # 타이머 측정 시작
                
                elapsed_time = current_time - both_hands_start_time
                
                # 1초 유지 시 승패 판정 실행
                if elapsed_time >= 1.0:
                    if left_choice == right_choice:
                        game_result = f"Draw! ({left_choice} vs {right_choice})"
                    elif (left_choice == "Scissors" and right_choice == "Paper") or \
                     (left_choice == "Rock" and right_choice == "Scissors") or \
                     (left_choice == "Paper" and right_choice == "Rock"):
                        game_result = f"Left Win! ({left_choice} vs {right_choice})"
                        score_left += 1
                    else:
                        game_result = f"Right Win! ({left_choice} vs {right_choice})"
                        score_right += 1

                    # 상태 리셋 및 쿨타임 갱신
                    both_hands_start_time = None
                    last_game_time = current_time
                else:
                    # 1초 대기 중 카운트다운 표시
                    game_result = f"Hold position... {1.0 - elapsed_time:.1f}s"
            else:
                # 판정 직후 쿨타임 동안 대기
                game_result = f"Next round in {COOLDOWN_TIME - (current_time - last_game_time):.1f}s"
        else:
            # 손이 인식 범위에서 벗어나거나 자세가 흐트러지면 타이머 초기화
            both_hands_start_time = None
            if current_time - last_game_time > COOLDOWN_TIME:
                game_result = "Show BOTH hands clearly!"

        # ======================================================================
        # 5. UI 오버레이 텍스트 출력
        # ======================================================================
        cv2.putText(frame, f"Score - Left: {score_left} | Right: {score_right}", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
        
        cv2.putText(frame, f"Left: {left_choice} | Right: {right_choice}", (20, 80),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        
        cv2.putText(frame, f"Result: {game_result}", (20, 130),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

        cv2.putText(frame, "Press 'q' or ESC to Exit", (20, h - 20),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (180, 180, 180), 1)

        cv2.imshow("Auto 2-Hand Rock Paper Scissors", frame)

        key = cv2.waitKey(5) & 0xFF
        if key == 27 or key == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import pyautogui

# %%
# 화면 크기 출력 (예: 1920x1080)
width, height = pyautogui.size()

# 현재 마우스 커서 위치 가져오기
x, y = pyautogui.position()

# 마우스 이동 (X: 100, Y: 200 위치로 1초 동안 이동)
pyautogui.moveTo(100, 200, duration=1.0)

# 클릭 제어
pyautogui.click()                      # 좌클릭
pyautogui.doubleClick()                # 더블 클릭
pyautogui.rightClick()                 # 우클릭
pyautogui.click(x=500, y=500)          # 특정 좌표 클릭

# 스크롤 (양수는 위로, 음수는 아래로)
pyautogui.scroll(-500)

# %%
# 문자열 입력 (한글은 pyperclip 라이브러리와 조합 필요, 영문/숫자 기본 지원)
pyautogui.write('Hello World!', interval=0.1)

# 특정 키 누르기
pyautogui.press('enter')
pyautogui.press('esc')

# 조합키 입력 (예: Ctrl + C, Ctrl + V)
pyautogui.hotkey('ctrl', 'c')
pyautogui.hotkey('ctrl', 'v')

# %%
# OpenCV 라이브러리: 비디오 프레임 캡처, 좌표 변환, 화면 시각화 담당
import cv2

# MediaPipe 라이브러리: 손 관절(21개 랜드마크) 추론을 담당
import mediapipe as mp

# PyAutoGUI 라이브러리: 파이썬으로 진짜 마우스 이동 및 클릭 제어
import pyautogui

# time 라이브러리: MediaPipe Tasks API에 넘겨줄 타임스탬프 생성용
import time

# math 라이브러리: 엄지와 검지 손가락 끝 사이의 유클리드 거리를 계산용
import math

# ==============================================================================
# 1. PyAutoGUI 환경 설정 및 모니터 해상도 구하기
# ==============================================================================
# 마우스 커서가 화면 모서리에 닿았을 때 발생할 수 있는 파이썬 예외 강제 종료 방지
pyautogui.FAILSAFE = False

# 마우스 동작 간 기본 대기 시간을 0.01초로 짧게 설정하여 커서 반응 속도 향상
pyautogui.PAUSE = 0.01

# 현재 사용 중인 모니터 화면의 전체 가로(screen_w), 세로(screen_h) 해상도 획득
screen_w, screen_h = pyautogui.size()
print(screen_w, screen_h)

# ==============================================================================
# 2. MediaPipe Tasks API 설정 및 모델 로드
# ==============================================================================
# BaseOptions: .task 모델 파일 경로 지정용 클래스
BaseOptions = mp.tasks.BaseOptions

# HandLandmarker: 실제 손 관절 좌표 추론 클래스
HandLandmarker = mp.tasks.vision.HandLandmarker

# HandLandmarkerOptions: 신뢰도, 추론 모드, 손 개수 등 세부 옵션 지정 클래스
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions

# VisionRunningMode: 비디오 프레임 스트림 방식 선택용 클래스
VisionRunningMode = mp.tasks.vision.RunningMode

# 손 관절 마디 연결 정보 정의 (시각화 목적)
HAND_CONNECTIONS = [
    (0, 1), (1, 2), (2, 3), (3, 4),        # 엄지손가락
    (0, 5), (5, 6), (6, 7), (7, 8),        # 검지손가락
    (5, 9), (9, 10), (10, 11), (11, 12),   # 중지손가락
    (9, 13), (13, 14), (14, 15), (15, 16), # 약지손가락
    (13, 17), (0, 17), (17, 18), (18, 19), (19, 20) # 새끼손가락
]

# HandLandmarker 모델 세부 옵션 지정
options = HandLandmarkerOptions(
    # 로컬 경로에 있는 모델(.task) 지정
    base_options=BaseOptions(model_asset_path='hand_landmarker.task'),
    # 실시간 비디오 스트림 처리 모드로 설정
    running_mode=VisionRunningMode.VIDEO,
    # 최대 인식할 손 개수 (마우스 제어이므로 1개로 제한)
    num_hands=1,
    # 최초 손 감지 신뢰도 임계값
    min_hand_detection_confidence=0.5,
    # 지속 손 추적 신뢰도 임계값
    min_tracking_confidence=0.5
)

# 기본 웹캠 캡처 객체 생성 (0번 카메라)
cap = cv2.VideoCapture(0)

# 이전 프레임의 마우스 커서 위치 기록용 변수 (부드러운 보정 계산용)
prev_x, prev_y = 0, 0

# 마우스 커서의 떨림 현상을 완화하기 위한 보정 비율 (값이 클수록 부드럽지만 약간의 딜레이 발생)
smoothing = 5

# 클릭 상태를 유지/해제하여 프레임마다 연타로 클릭되는 현상을 방지하는 플래그
is_clicked = False

# 카메라 가장자리 여백 영역 설정 (손을 웹캠 끝까지 움직이지 않아도 모니터 구석에 닿도록 함)
margin = 100 

# ==============================================================================
# 3. 실시간 가상 마우스 루프 시작
# ==============================================================================
# Landmarker 인스턴스 자동 자원 관리를 위한 with 블록 시작
with HandLandmarker.create_from_options(options) as landmarker:
    while cap.isOpened():
        # 웹캠 프레임 가져오기 (ret: 성공 여부, frame: BGR 이미지)
        ret, frame = cap.read()
        if not ret:
            break

        # 사용자가 거울 보듯 자연스럽게 조작하도록 좌우 반전
        frame = cv2.flip(frame, 1)
        
        # 현재 카메라 프레임의 높이(h), 너비(w) 추출
        h, w, _ = frame.shape
        
        # OpenCV의 BGR 이미지를 MediaPipe용 RGB 이미지로 변환
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # NumPy 이미지 배열을 MediaPipe 전용 Image 객체로 래핑
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        
        # VIDEO 모드 필수 요구사항: 밀리초(ms) 단위의 단조 증가 타임스탬프 계산
        frame_timestamp_ms = int(time.time() * 1000)
        
        # MediaPipe 모델로 손 좌표 추론 실행
        result = landmarker.detect_for_video(mp_image, frame_timestamp_ms)

        # 카메라 화면 상에 노란색 가상 조작 영역 Box 표시
        cv2.rectangle(frame, (margin, margin), (w - margin, h - margin), (255, 255, 0), 2)

        # 손 관절 추론 결과가 존재하는 경우
        if result.hand_landmarks:
            for hand_landmarks in result.hand_landmarks:
                # 21개 관절의 픽셀 좌표를 보관할 리스트
                pixel_coords = []
                
                # 랜드마크 정규화 좌표(0.0~1.0)를 해상도에 맞는 픽셀 좌표로 환산하여 시각화
                for lm in hand_landmarks:
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    pixel_coords.append((cx, cy))
                    # 관절 지점에 초록색 점 그리기
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 0), -1)

                # 손가락 관절 간 파란색 선으로 연결선 그리기
                for start_idx, end_idx in HAND_CONNECTIONS:
                    cv2.line(frame, pixel_coords[start_idx], pixel_coords[end_idx], (255, 0, 0), 2)

                # 마우스 커서 조작 및 클릭 판정에 사용할 엄지 끝(4번)과 검지 끝(8번) 좌표 추출
                thumb_x, thumb_y = pixel_coords[4]
                index_x, index_y = pixel_coords[8]

                # --------------------------------------------------------------
                # 3-1. 마우스 이동 처리 (검지 손가락 끝 좌표 기준)
                # --------------------------------------------------------------
                # 카메라 조작 영역(margin 적용 영역) 좌표를 실제 모니터 해상도 좌표 비율로 선형 매핑
                target_x = (index_x - margin) / (w - 2 * margin) * screen_w
                target_y = (index_y - margin) / (h - 2 * margin) * screen_h

                # 모니터 화면 바깥으로 커서가 벗어나지 않도록 좌표값 상하한 제한
                target_x = max(0, min(screen_w, target_x))
                target_y = max(0, min(screen_h, target_y))

                # 이동 보정 알고리즘: 이전 좌표와 목표 좌표 사이를 보정하여 손떨림으로 인한 마우스 튐 방지
                curr_x = prev_x + (target_x - prev_x) / smoothing
                curr_y = prev_y + (target_y - prev_y) / smoothing

                # PyAutoGUI를 통해 실제 OS 마우스 위치 이동
                pyautogui.moveTo(curr_x, curr_y)
                
                # 다음 프레임 보정을 위한 현재 위치 저장
                prev_x, prev_y = curr_x, curr_y

                # --------------------------------------------------------------
                # 3-2. 마우스 좌클릭 처리 (검지와 엄지 손가락 끝 간 거리 계산)
                # --------------------------------------------------------------
                # 2차원 피타고라스 정리(유클리드 거리)로 두 손가락 끝의 픽셀 거리 계산
                distance = math.hypot(index_x - thumb_x, index_y - thumb_y)
                
                # 엄지와 검지 사이를 연결하는 노란색 직선 그리기 (집게 동작 시각화)
                cv2.line(frame, (thumb_x, thumb_y), (index_x, index_y), (0, 255, 255), 2)

                # 거리가 30픽셀 미만으로 좁혀지면(손가락 맞닿음/집게 동작) 클릭 인식
                if distance < 30:
                    # 클릭 동작 인식 시 검지 끝에 빨간색 동그라미 표시
                    cv2.circle(frame, (index_x, index_y), 10, (0, 0, 255), -1)
                    
                    # 단발성 클릭 처리를 위해 is_clicked 플래그 사용
                    if not is_clicked:
                        pyautogui.click() # 좌클릭 실행
                        is_clicked = True  # 클릭 중 상태로 전환
                else:
                    # 손가락을 떼면 클릭 상태 해제
                    is_clicked = False

        # 가상 마우스 조작 화면 출력
        cv2.imshow("Virtual Mouse", frame)

        # 5밀리초 동안 키 입력 대기 ('q' 키 또는 ESC 입력 시 반복 탈출)
        key = cv2.waitKey(5) & 0xFF
        if key == 27 or key == ord('q'):
            break

# ==============================================================================
# 4. 자원 해제
# ==============================================================================
# 웹캠 장치 연결 해제
cap.release()

# 모든 OpenCV 그래픽 창 닫기
cv2.destroyAllWindows()
# Out:
# 1920 1080

# %%
# OpenCV 라이브러리: 카메라 영상 처리 및 화면 시각화 담당
import cv2

# MediaPipe 라이브러리: 얼굴 랜드마크 추론 모듈 제공
import mediapipe as mp

# time 라이브러리: MediaPipe Video 모드에 필요한 타임스탬프 계산용
import time

# ==============================================================================
# 1. MediaPipe Tasks API 필수 모듈 및 설정 로드
# ==============================================================================
BaseOptions = mp.tasks.BaseOptions
FaceLandmarker = mp.tasks.vision.FaceLandmarker
FaceLandmarkerOptions = mp.tasks.vision.FaceLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

# Face Landmarker 세부 설정
options = FaceLandmarkerOptions(
    # 모델 파일 경로 지정 (.task 파일)
    base_options=BaseOptions(model_asset_path='face_landmarker.task'),
    # 실시간 비디오 스트림 처리 모드 선택
    running_mode=VisionRunningMode.VIDEO,
    # 감지할 최대 얼굴 개수
    num_faces=1,
    # 얼굴 감지 최저 신뢰도 (50% 이상)
    min_face_detection_confidence=0.5,
    # 프레임 간 추적 최저 신뢰도 (50% 이상)
    min_tracking_confidence=0.5
)

# 0번 인덱스 기본 웹캠 연결
cap = cv2.VideoCapture(0)

# ==============================================================================
# 2. 실시간 얼굴 특징점 시각화 루프
# ==============================================================================
with FaceLandmarker.create_from_options(options) as landmarker:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # 거울 모드를 위한 좌우 반전
        frame = cv2.flip(frame, 1)
        h, w, _ = frame.shape

        # BGR 이미지를 RGB 이미지로 변환
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # MediaPipe 전용 Image 객체로 래핑
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)

        # 밀리초(ms) 단위 타임스탬프 계산
        frame_timestamp_ms = int(time.time() * 1000)

        # 얼굴 랜드마크 추론 실행
        result = landmarker.detect_for_video(mp_image, frame_timestamp_ms)

        # 얼굴이 감지되었을 경우 특징점 그리기
        if result.face_landmarks:
            for face_landmarks in result.face_landmarks:
                # --------------------------------------------------------------
                # A. 468개 전체 입체 특징점(점) 찍기
                # --------------------------------------------------------------
                for lm in face_landmarks:
                    # 정규화된 좌표(0.0~1.0)를 실제 화면 픽셀 좌표로 환산
                    cx, cy = int(lm.x * w), int(lm.y * h)

                    # 관절 위치에 작은 초록색 원 그리기 (반지름: 1px)
                    cv2.circle(frame, (cx, cy), 1, (0, 255, 0), -1)

                # --------------------------------------------------------------
                # B. 주요 부위 강조 표시 (눈, 눈썹, 입술, 얼굴 윤곽 등)
                # --------------------------------------------------------------
                # 주요 랜드마크 인덱스 포인트 예시
                # 1번: 코 끝, 10번: 이마 중앙 상단, 152번: 턱 끝
                # 33번: 왼쪽 눈 가장자리, 263번: 오른쪽 눈 가장자리
                key_indices = [1, 10, 152, 33, 263, 61, 291]

                for idx in key_indices:
                    lm = face_landmarks[idx]
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    # 핵심 특징점은 빨간색 큰 원으로 강조
                    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)

        # 화면 안내 문구 표시
        cv2.putText(frame, "Face Landmarks Visualization", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
        cv2.putText(frame, "Press 'q' or ESC to exit", (20, h - 20),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (180, 180, 180), 1)

        # 결과 프레임 출력
        cv2.imshow("Face Landmarks", frame)

        # 'q' 키 또는 ESC 키 입력 시 종료
        key = cv2.waitKey(5) & 0xFF
        if key == 27 or key == ord('q'):
            break

# ==============================================================================
# 3. 자원 해제
# ==============================================================================
# OpenCv 카메라 비디오 스트림 연결 해제
cap.release()

# 모든 OpenCV 그래픽 창 닫기
cv2.destroyAllWindows()

# %%
# OpenCV 라이브러리: 비디오 프레임 캡처, 이미지 가공, 텍스트/도형 시각화, 화면 출력 담당
import cv2

# MediaPipe 라이브러리: 인공지능 기반 손 관절 추론 및 얼굴 랜드마크 데이터 제공
import mediapipe as mp

# random 라이브러리: 컴퓨터의 가위/바위/보 선택을 무작위로 추출하기 위해 사용
import random

# time 라이브러리: MediaPipe Video 모드 실행 시 필요한 밀리초(ms) 단위 타임스탬프 계산용
import time

# numpy 라이브러리: 고성능 행렬 연산 및 이미지 배열 데이터 처리를 위한 모듈
import numpy as np

# ==============================================================================
# 1. MediaPipe Tasks API 모듈 로드 및 객체 정의
# ==============================================================================
# BaseOptions: .task 모델 파일의 위치 및 실행 디바이스(CPU/GPU) 환경 설정 모듈
BaseOptions = mp.tasks.BaseOptions

# HandLandmarker: 21개 손 관절 좌표 수집 및 추론 메인 클래스
HandLandmarker = mp.tasks.vision.HandLandmarker

# HandLandmarkerOptions: 손 탐지 임계값, 감지 손 개수, 비디오 모드 세팅 클래스
HandLandmarkerOptions = mp.tasks.vision.HandLandmarkerOptions

# FaceLandmarker: 468개 얼굴 이목구비 및 입체 Mesh 좌표 추론 메인 클래스
FaceLandmarker = mp.tasks.vision.FaceLandmarker

# FaceLandmarkerOptions: 얼굴 탐지 임계값, 인식 얼굴 개수, 비디오 모드 세팅 클래스
FaceLandmarkerOptions = mp.tasks.vision.FaceLandmarkerOptions

# VisionRunningMode: 처리 모드 설정 (LIVE_STREAM, VIDEO, IMAGE 중 VIDEO 선택)
VisionRunningMode = mp.tasks.vision.RunningMode

# 손 관절 뼈대를 시각적으로 이어줄 21개 랜드마크 인덱스 연결 쌍 정의
HAND_CONNECTIONS = [
    (0, 1), (1, 2), (2, 3), (3, 4),        # 엄지손가락 마디 연결선 (손목 -> 손가락 끝)
    (0, 5), (5, 6), (6, 7), (7, 8),        # 검지손가락 마디 연결선
    (5, 9), (9, 10), (10, 11), (11, 12),   # 중지손가락 마디 연결선
    (9, 13), (13, 14), (14, 15), (15, 16), # 약지손가락 마디 연결선
    (13, 17), (0, 17), (17, 18), (18, 19), (19, 20) # 새끼손가락 마디 연결선
]

# ==============================================================================
# 2. 투명 배경(Alpha 채널) PNG 가면 이미지 알파 블렌딩 합성 함수
# ==============================================================================
def overlay_transparent(background, overlay, x, y, size=None):
    """
    background: 배경이 될 카메라 프레임 (BGR 이미지)
    overlay: 씌울 가면 이미지 (4채널 BGRA 투명 PNG)
    x, y: 가면이 위치할 좌상단 픽셀 좌표
    size: 변경할 (너비, 높이) 크기 튜플
    """
    # 사용자의 얼굴 크기에 맞춰 가면 이미지 크기를 동적으로 조정
    if size and size[0] > 0 and size[1] > 0:
        overlay = cv2.resize(overlay, size, interpolation=cv2.INTER_AREA)

    # 가면 이미지의 높이, 너비, 채널 수 추출
    h, w, c = overlay.shape
    bg_h, bg_w, _ = background.shape

    # 가면이 카메라 화면 바깥으로 나갈 경우 잘려나갈 경계 범위 계산 (오류 방지)
    bg_y1, bg_y2 = max(0, y), min(bg_h, y + h)
    bg_x1, bg_x2 = max(0, x), min(bg_w, x + w)

    overlay_y1, overlay_y2 = max(0, -y), h - max(0, (y + h) - bg_h)
    overlay_x1, overlay_x2 = max(0, -x), w - max(0, (x + w) - bg_w)

    # 가면이 화면 영역 전체를 벗어났다면 원본 이미지 그대로 반환
    if overlay_y1 >= overlay_y2 or overlay_x1 >= overlay_x2:
        return background

    # 4번째 채널인 Alpha(투명도: 0~255) 값을 0.0 ~ 1.0 비율 범위로 정규화
    alpha = overlay[overlay_y1:overlay_y2, overlay_x1:overlay_x2, 3] / 255.0

    # B, G, R 3개 색상 채널별로 투명 합성 연산 수행 (알파 블렌딩 공식)
    for color in range(3):
        background[bg_y1:bg_y2, bg_x1:bg_x2, color] = (
            alpha * overlay[overlay_y1:overlay_y2, overlay_x1:overlay_x2, color] +
            (1.0 - alpha) * background[bg_y1:bg_y2, bg_x1:bg_x2, color]
        )
    return background

# ==============================================================================
# 3. 손 관절 좌표 기반 가위, 바위, 보 동작 판별 함수
# ==============================================================================
def classify_rps(landmarks):
    """
    landmarks: MediaPipe 손 관절 21개 좌표 리스트
    반환값: "가위", "바위", "보", "알 수 없음" 문자열
    """
    # 검지 뿌리(5)와 새끼 뿌리(17)의 x좌표를 비교하여 손바닥이 앞/뒤 중 어디를 보는지 확인
    if landmarks[5].x > landmarks[17].x:
        # 오른손/손바닥이 보일 때: 엄지 끝(4)이 엄지 마디(3)보다 우측(x가 더 큼)이면 펴진 상태
        thumb_open = landmarks[4].x > landmarks[3].x
    else:
        # 왼손/손등이 보일 때: 엄지 끝(4)이 엄지 마디(3)보다 좌측(x가 더 작음)이면 펴진 상태
        thumb_open = landmarks[4].x < landmarks[3].x

    # 나머지 손가락들은 y축 좌표 비교 (화면 상단이 0, 하단이 1이므로 y가 작을수록 펴진 것)
    index_open = landmarks[8].y < landmarks[6].y    # 검지 끝(8)이 관절(6)보다 위인지 확인
    middle_open = landmarks[12].y < landmarks[10].y  # 중지 끝(12)이 관절(10)보다 위인지 확인
    ring_open = landmarks[16].y < landmarks[14].y    # 약지 끝(16)이 관절(14)보다 위인지 확인
    pinky_open = landmarks[20].y < landmarks[18].y   # 새끼 끝(20)이 관절(18)보다 위인지 확인

    # 가위 조건 1: 엄지와 검지가 펴지고 나머지 굽힘 (권총 모양 가위)
    scissors_thumb_index = thumb_open and index_open and (not middle_open) and (not ring_open) and (not pinky_open)
    # 가위 조건 2: 검지와 중지가 펴지고 나머지 굽힘 (V 자 모양 가위)
    scissors_index_middle = (not thumb_open) and index_open and middle_open and (not ring_open) and (not pinky_open)

    # 가위 조건 1 또는 2 중 하나라도 만족하면 "가위"
    if scissors_thumb_index or scissors_index_middle:
        return "가위"
    # 모든 손가락 5개가 펴져 있다면 "보"
    elif thumb_open and index_open and middle_open and ring_open and pinky_open:
        return "보"
    # 모든 손가락 5개가 굽혀져 있다면 "바위"
    elif (not thumb_open) and (not index_open) and (not middle_open) and (not ring_open) and (not pinky_open):
        return "바위"
    # 규정되지 않은 손모양일 경우 "알 수 없음"
    else:
        return "알 수 없음"

# ==============================================================================
# 4. 가면 이미지 로드 및 MediaPipe 모델 옵션 초기화
# ==============================================================================
# 동작 판별 텍스트와 매핑되는 마스크 PNG 파일 불러오기 (4채널 IMREAD_UNCHANGED 옵션 필수)
masks = {
    "바위": cv2.imread('mask_rock.png', cv2.IMREAD_UNCHANGED),
    "가위": cv2.imread('mask_scissors.png', cv2.IMREAD_UNCHANGED),
    "보": cv2.imread('mask_paper.png', cv2.IMREAD_UNCHANGED)
}

# 얼굴 랜드마크 모델 옵션 세팅
face_options = FaceLandmarkerOptions(
    base_options=BaseOptions(model_asset_path='face_landmarker.task'), # 모델 파일 지정
    running_mode=VisionRunningMode.VIDEO,                             # 실시간 비디오 스트림 처리 모드
    num_faces=1,                                                      # 탐지할 최대 얼굴 수 (1개)
    min_face_detection_confidence=0.5,                                # 얼굴 탐지 임계값 (50%)
    min_tracking_confidence=0.5                                       # 얼굴 추적 임계값 (50%)
)

# 손 관절 모델 옵션 세팅
hand_options = HandLandmarkerOptions(
    base_options=BaseOptions(model_asset_path='hand_landmarker.task'), # 모델 파일 지정
    running_mode=VisionRunningMode.VIDEO,                             # 실시간 비디오 스트림 처리 모드
    num_hands=1,                                                      # 탐지할 최대 손 수 (1개로 혼선 방지)
    min_hand_detection_confidence=0.5,                                # 손 탐지 임계값 (50%)
    min_tracking_confidence=0.5                                       # 손 추적 임계값 (50%)
)

# 기본 시스템 카메라(인덱스 0번 웹캠) 오픈
cap = cv2.VideoCapture(0)

# 가위바위보 게임 상태 관리 변수 세팅
choices = ["가위", "바위", "보"]   # 컴퓨터 무작위 추첨 후보군 리스트
computer_choice = None           # 컴퓨터가 선택한 가위/바위/보 저장 변수
user_choice = None               # 플레이어가 선택한 가위/바위/보 저장 변수
game_result = "Space키를 눌러 가위바위보 시작!" # 게임 진행 현황 안내 문구
score_user = 0                   # 사용자의 누적 점수
score_computer = 0               # 컴퓨터의 누적 점수

# ==============================================================================
# 5. 실시간 추론 및 종합 처리 메인 루프
# ==============================================================================
# FaceLandmarker와 HandLandmarker 자원을 동시에 안전하게 오픈
with FaceLandmarker.create_from_options(face_options) as face_landmarker, \
     HandLandmarker.create_from_options(hand_options) as hand_landmarker:
    
    # 웹캠 연결이 정상이면 계속 반복 실행
    while cap.isOpened():
        # 프레임 단위로 카메라 화면 읽기 (ret: 성공여부, frame: BGR 이미지)
        ret, frame = cap.read()
        if not ret:
            break

        # 사용자가 거울을 보는 것처럼 느낄 수 있도록 화면 좌우 반전
        frame = cv2.flip(frame, 1)
        
        # 픽셀 좌표 계산을 위한 현재 프레임의 높이(h)와 너비(w) 추출
        h, w, _ = frame.shape
        
        # OpenCV의 BGR 채널 포맷을 MediaPipe 표준 RGB 채널로 변환
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # NumPy 이미지 배열을 MediaPipe 프레임워크 전용 Image 객체로 패킹
        mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
        
        # VIDEO 실행 모드 규격에 요구되는 밀리초(ms) 단위의 현재 시간 타임스탬프 계산
        frame_timestamp_ms = int(time.time() * 1000)
        
        # AI 모델에 이미지를 전달하여 얼굴 및 손 동작 추론 결과 동시 추출
        face_result = face_landmarker.detect_for_video(mp_image, frame_timestamp_ms)
        hand_result = hand_landmarker.detect_for_video(mp_image, frame_timestamp_ms)

        # ----------------------------------------------------------------------
        # A. 손 관절 시각화 및 가위바위보 동작 분류
        # ----------------------------------------------------------------------
        # 손 감지가 되지 않았을 때의 기본 안내 문구
        current_hand_gesture = "손을 올려주세요"

        # 카메라에 손이 인식되어 결과 좌표가 존재하는 경우
        if hand_result.hand_landmarks:
            for hand_landmarks in hand_result.hand_landmarks:
                # 21개 관절의 실제 픽셀 좌표를 저장할 리스트
                pixel_coords = []
                
                # 21개 랜드마크를 순회하며 화면 상의 (x, y) 픽셀 위치로 변환
                for lm in hand_landmarks:
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    pixel_coords.append((cx, cy))
                    # 관절 위치마다 노란색 원 그리기
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 255), -1)

                # HAND_CONNECTIONS 인덱스 연결 정보에 따라 파란색 뼈대 라인 그리기
                for start_idx, end_idx in HAND_CONNECTIONS:
                    cv2.line(frame, pixel_coords[start_idx], pixel_coords[end_idx], (255, 0, 0), 2)

                # 손 관절 좌표 데이터를 판별 함수에 전달하여 가위/바위/보 판단
                current_hand_gesture = classify_rps(hand_landmarks)

        # ----------------------------------------------------------------------
        # B. 얼굴 특징점 표현 및 마스크 이미지 동적 오버레이
        # ----------------------------------------------------------------------
        # 카메라에 얼굴이 인식되어 결과 좌표가 존재하는 경우
        if face_result.face_landmarks:
            for face_landmarks in face_result.face_landmarks:
                # 1. 얼굴 전체 468개 랜드마크에 초록색 미세 점 그리기
                for lm in face_landmarks:
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    cv2.circle(frame, (cx, cy), 1, (0, 255, 0), -1)

                # 2. 이목구비 핵심 관절 포인트(코 끝, 이마, 턱, 눈 외각, 입술 끝) 강조
                key_indices = [1, 10, 152, 33, 263, 61, 291]
                for idx in key_indices:
                    lm = face_landmarks[idx]
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    # 중요 포인트는 빨간색 큰 원으로 강조
                    cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)

                # 3. 손 모양(가위/바위/보)에 해당하는 마스크가 정상 로드되어 있다면 오버레이 처리
                if current_hand_gesture in masks and masks[current_hand_gesture] is not None:
                    mask_img = masks[current_hand_gesture]

                    # 얼굴 윤곽의 사방 끝 관절 좌표 추출 (10: 이마 상단, 152: 턱 끝, 234: 왼쪽 광대, 454: 오른쪽 광대)
                    left_x = int(face_landmarks[234].x * w)
                    right_x = int(face_landmarks[454].x * w)
                    top_y = int(face_landmarks[10].y * h)
                    bottom_y = int(face_landmarks[152].y * h)

                    # 감지된 얼굴의 가로/세로 폭을 측정하고 약간의 여유분(1.3배) 추가
                    mask_w = int((right_x - left_x) * 1.3)
                    mask_h = int((bottom_y - top_y) * 1.3)

                    # 얼굴 중심점 위치 계산
                    center_x = (left_x + right_x) // 2
                    center_y = (top_y + bottom_y) // 2
                    
                    # 가면의 좌상단 시작 픽셀 좌표 계산
                    mask_x = center_x - (mask_w // 2)
                    mask_y = center_y - (mask_h // 2)

                    # 투명 배경 오버레이 함수를 호출하여 화면에 가면 합성
                    frame = overlay_transparent(frame, mask_img, mask_x, mask_y, (mask_w, mask_h))

        # ----------------------------------------------------------------------
        # C. 게임 화면 UI 및 정보 텍스트 오버레이
        # ----------------------------------------------------------------------
        # 상단 누적 스코어 현황 출력 (흰색 텍스트)
        cv2.putText(frame, f"Score - You: {score_user} | Com: {score_computer}", (20, 40),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2)
        
        # 현재 카메라에 감지 중인 손 모양 텍스트 출력 (노란색 텍스트)
        cv2.putText(frame, f"Detected Hand: {current_hand_gesture}", (20, 80),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
        
        # 가위바위보 대결 승패 결과 및 안내 문구 출력 (초록색 텍스트)
        cv2.putText(frame, f"Result: {game_result}", (20, 130),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

        # 컴퓨터가 가위/바위/보 중 하나를 낸 상태라면 컴퓨터의 선택 출력 (연보라색 텍스트)
        if computer_choice:
            cv2.putText(frame, f"Com Choice: {computer_choice}", (20, 170),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (200, 200, 250), 2)

        # 화면 하단 조작 키 사용 방법 안내 텍스트 출력 (회색 텍스트)
        cv2.putText(frame, "Press 'Space' to Play / 'q' or ESC to Exit", (20, h - 20),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (180, 180, 180), 1)

        # 가공 완료된最終 프레임을 화면 윈도우 창에 렌더링
        cv2.imshow("Face Mask & Rock Paper Scissors Game", frame)

        # 키보드 입력을 5ms 동안 대기
        key = cv2.waitKey(5) & 0xFF
        
        # 스페이스바(ASCII 번호 32)를 누르면 판정 연산 실행
        if key == 32:
            # 인식된 손 모양이 가위, 바위, 보 중 하나로 확실할 때만 게임 진행
            if current_hand_gesture in choices:
                # 플레이어 선택값 확정
                user_choice = current_hand_gesture
                # 컴퓨터 무작위 추첨
                computer_choice = random.choice(choices)

                # 비긴 경우 처리
                if user_choice == computer_choice:
                    game_result = f"Draw! (You: {user_choice} vs Com: {computer_choice})"
                
                # 사용자가 승리하는 조건 판별 (가위>보, 바위>가위, 보>바위)
                elif (user_choice == "가위" and computer_choice == "보") or \
                     (user_choice == "바위" and computer_choice == "가위") or \
                     (user_choice == "보" and computer_choice == "바위"):
                    game_result = f"You Win! (You: {user_choice} vs Com: {computer_choice})"
                    score_user += 1 # 플레이어 점수 +1
                
                # 컴퓨터가 승리한 경우 처리
                else:
                    game_result = f"You Lose! (You: {user_choice} vs Com: {computer_choice})"
                    score_computer += 1 # 컴퓨터 점수 +1
            
            # 손 모양이 부정확하거나 화면에 손이 없는 경우 예외 처리
            else:
                game_result = "Hand position unclear! Try again."

        # 'q' 키 또는 ESC 키(ASCII 번호 27) 누를 시 루프 종료
        elif key == 27 or key == ord('q'):
            break

# ==============================================================================
# 6. 자원 해제 및 종료 처리
# ==============================================================================
# 카메라 디바이스 연결 해제 및 리소스 반환
cap.release()

# 오픈된 모든 OpenCV GUI 창 닫기
cv2.destroyAllWindows()
